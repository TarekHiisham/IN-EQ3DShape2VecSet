# %%
# !pip install e3nn
# !pip install --no-index \
  --find-links https://data.pyg.org/whl/torch-2.10.0+cu128.html \
  torch-cluster
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.7/450.7 kB 8.0 MB/s eta 0:00:00ta 0:00:01
# ...
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 35.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !git clone https://github.com/TarekHiisham/IN-EQ3DShape2VecSet.git
# Out:
# Cloning into 'IN-EQ3DShape2VecSet'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 160 (delta 93), reused 108 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (160/160), 102.96 KiB | 1.69 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# %cd /kaggle/working/IN-EQ3DShape2VecSet
# !git pull https://github.com/TarekHiisham/IN-EQ3DShape2VecSet.git
# Out:
# /kaggle/working/IN-EQ3DShape2VecSet
# From https://github.com/TarekHiisham/IN-EQ3DShape2VecSet
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 6.2 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.0/750.0 kB 21.0 MB/s eta 0:00:0000:01
# ...

# %%
! python main_ae.py --mesh_folder /kaggle/input/datasets/tarekhisham/shapenet-03797390-class/surfaces \
                  --point_folder /kaggle/input/datasets/tarekhisham/shapenet-03797390-class/occupancies \
                  --finetune /kaggle/input/models/tarekelwasif/pretrained-ae-d512-m512/pytorch/default/1/checkpoint-199.pth \
                  --preservation inv \
                  --batch_size 32 \
                  --epochs 100 \
                  --num_workers 4 \
                  --output_dir /kaggle/working/outputs/
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Not using distributed mode
# [19:40:25.451316] job dir: /kaggle/working/IN-EQ3DShape2VecSet
# [19:40:25.451460] Namespace(batch_size=32,
# epochs=100,
# accum_iter=1,
# model='ae_d512_m512',
# point_cloud_size=2048,
# preservation='inv',
# clip_grad=None,
# weight_decay=0.05,
# lr=None,
# blr=0.0001,
# layer_decay=0.75,
# min_lr=1e-06,
# warmup_epochs=10,
# mesh_folder='/kaggle/input/datasets/tarekhisham/shapenet-03797390-class/surfaces',
# point_folder='/kaggle/input/datasets/tarekhisham/shapenet-03797390-class/occupancies',
# output_dir='/kaggle/working/outputs/',
# log_dir='./output/',
# device='cuda',
# seed=0,
# ...

# %%
! python main_ae.py --mesh_folder /kaggle/input/datasets/tarekhisham/shapenet-03797390-class/surfaces \
                  --point_folder /kaggle/input/datasets/tarekhisham/shapenet-03797390-class/occupancies \
                  --finetune /kaggle/input/models/tarekelwasif/pretrained-ae-d512-m512/pytorch/default/1/checkpoint-199.pth \
                  --preservation equ \
                  --batch_size 32 \
                  --epochs 100 \
                  --num_workers 4 \
                  --output_dir /kaggle/working/outputs/
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Not using distributed mode
# [13:04:16.572434] job dir: /kaggle/working/IN-EQ3DShape2VecSet
# [13:04:16.572592] Namespace(batch_size=32,
# epochs=100,
# accum_iter=1,
# model='ae_d512_m512',
# point_cloud_size=2048,
# preservation='equ',
# clip_grad=None,
# weight_decay=0.05,
# lr=None,
# blr=0.0001,
# layer_decay=0.75,
# min_lr=1e-06,
# warmup_epochs=10,
# mesh_folder='/kaggle/input/datasets/tarekhisham/shapenet-03797390-class/surfaces',
# point_folder='/kaggle/input/datasets/tarekhisham/shapenet-03797390-class/occupancies',
# output_dir='/kaggle/working/outputs/',
# log_dir='./output/',
# device='cuda',
# seed=0,
# ...
